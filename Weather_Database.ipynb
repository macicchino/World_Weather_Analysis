# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %%
#pip install citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)# YOUR CODE HERE
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)# YOUR CODE HERE

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs) # YOUR CODE HERE
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs) # YOUR CODE HERE

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = [] # YOUR CODE HERE

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name # YOUR CODE HERE
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city) # YOUR CODE HERE
        
# Print the city count to confirm sufficient count
len(cities) # YOUR CODE HERE
# Out:
# 783

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3ac010e7bf363acfed0563ef7e7244f9

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tipitapa
# Processing Record 2 of Set 1 | fortuna
# Processing Record 3 of Set 1 | guiyang
# Processing Record 4 of Set 1 | talnakh
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | marawi
# Processing Record 7 of Set 1 | husavik
# Processing Record 8 of Set 1 | toamasina
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 1 | guadalupe y calvo
# Processing Record 15 of Set 1 | skelleftea
# Processing Record 16 of Set 1 | ust-maya
# Processing Record 17 of Set 1 | luocheng
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | carutapera
# Processing Record 21 of Set 1 | bogorodskoye
# Processing Record 22 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | narsaq
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | benghazi
# Processing Record 29 of Set 1 | erenhot
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | kununurra
# Processing Record 33 of Set 1 | broome
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 1 | praia da vitoria
# Processing Record 38 of Set 1 | guane
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | hit
# Processing Record 41 of Set 1 | luanda
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | west bay
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | tupelo
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | loei
# Processing Record 50 of Set 1 | talara
# Processing Record 1 of Set 2 | bay roberts
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 2 | san jose
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | san remigio
# Processing Record 9 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | sunrise manor
# Processing Record 13 of Set 2 | jodhpur
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | roald
# Processing Record 17 of Set 2 | calvinia
# Processing Record 18 of Set 2 | snezhnogorsk
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | sukumo
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | verkhnevilyuysk
# Processing Record 23 of Set 2 | takoradi
# Processing Record 24 of Set 2 | san mateo
# Processing Record 25 of Set 2 | bonavista
# Processing Record 26 of Set 2 | sistranda
# Processing Record 27 of Set 2 | rafiganj
# Processing Record 28 of Set 2 | salalah
# Processing Record 29 of Set 2 | lompoc
# Processing Record 30 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 2 | arrecife
# Processing Record 32 of Set 2 | lorengau
# Processing Record 33 of Set 2 | novobirilyussy
# Processing Record 34 of Set 2 | avanigadda
# Processing Record 35 of Set 2 | albanel
# Processing Record 36 of Set 2 | faya
# Processing Record 37 of Set 2 | kavieng
# Processing Record 38 of Set 2 | lebyazhye
# Processing Record 39 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 2 | palasa
# Processing Record 41 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 2 | sao filipe
# Processing Record 43 of Set 2 | comodoro rivadavia
# Processing Record 44 of Set 2 | nizhniy kuranakh
# Processing Record 45 of Set 2 | constantine
# Processing Record 46 of Set 2 | tautira
# Processing Record 47 of Set 2 | bethel
# Processing Record 48 of Set 2 | roches noires
# City not found. Skipping...
# Processing Record 49 of Set 2 | otradnoye
# Processing Record 50 of Set 2 | bluff
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | acapulco
# Processing Record 3 of Set 3 | katsuura
# Processing Record 4 of Set 3 | atuona
# Processing Record 5 of Set 3 | kuytun
# Processing Record 6 of Set 3 | mecca
# Processing Record 7 of Set 3 | salinopolis
# Processing Record 8 of Set 3 | marquette
# Processing Record 9 of Set 3 | mataura
# Processing Record 10 of Set 3 | hudiksvall
# Processing Record 11 of Set 3 | mayo
# Processing Record 12 of Set 3 | hobart
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | aksu
# Processing Record 15 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 3 | dzaoudzi
# Processing Record 17 of Set 3 | farah
# Processing Record 18 of Set 3 | krutikha
# Processing Record 19 of Set 3 | jubayl
# City not found. Skipping...
# Processing Record 20 of Set 3 | manyana
# Processing Record 21 of Set 3 | nouadhibou
# Processing Record 22 of Set 3 | bairiki
# Processing Record 23 of Set 3 | bowen
# Processing Record 24 of Set 3 | dumabato
# Processing Record 25 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 3 | pangnirtung
# Processing Record 27 of Set 3 | kharan
# Processing Record 28 of Set 3 | poya
# Processing Record 29 of Set 3 | ilulissat
# Processing Record 30 of Set 3 | lata
# Processing Record 31 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 3 | lasa
# Processing Record 35 of Set 3 | khani
# Processing Record 36 of Set 3 | coihaique
# Processing Record 37 of Set 3 | san policarpo
# Processing Record 38 of Set 3 | bengkulu
# Processing Record 39 of Set 3 | beira
# Processing Record 40 of Set 3 | flinders
# Processing Record 41 of Set 3 | dunedin
# Processing Record 42 of Set 3 | bilma
# Processing Record 43 of Set 3 | puerto ayora
# Processing Record 44 of Set 3 | charters towers
# Processing Record 45 of Set 3 | skjervoy
# Processing Record 46 of Set 3 | victoria
# Processing Record 47 of Set 3 | luderitz
# Processing Record 48 of Set 3 | kavaratti
# Processing Record 49 of Set 3 | manono
# Processing Record 50 of Set 3 | port elizabeth
# Processing Record 1 of Set 4 | tiksi
# Processing Record 2 of Set 4 | egvekinot
# Processing Record 3 of Set 4 | tuatapere
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | nikolskoye
# Processing Record 6 of Set 4 | urusha
# Processing Record 7 of Set 4 | lebu
# Processing Record 8 of Set 4 | chhagalnaiya
# Processing Record 9 of Set 4 | clyde river
# Processing Record 10 of Set 4 | whitehorse
# Processing Record 11 of Set 4 | navoi
# Processing Record 12 of Set 4 | necochea
# Processing Record 13 of Set 4 | itaueira
# Processing Record 14 of Set 4 | menongue
# Processing Record 15 of Set 4 | ancud
# Processing Record 16 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 4 | anchorage
# Processing Record 18 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 4 | ozinki
# Processing Record 20 of Set 4 | farafangana
# Processing Record 21 of Set 4 | kanye
# Processing Record 22 of Set 4 | bongor
# Processing Record 23 of Set 4 | somerset east
# Processing Record 24 of Set 4 | tungor
# Processing Record 25 of Set 4 | bauchi
# Processing Record 26 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 4 | guadalupe
# Processing Record 28 of Set 4 | baherden
# Processing Record 29 of Set 4 | san patricio
# Processing Record 30 of Set 4 | port hueneme
# Processing Record 31 of Set 4 | pailon
# Processing Record 32 of Set 4 | santa cruz do sul
# Processing Record 33 of Set 4 | cosala
# Processing Record 34 of Set 4 | brzesko
# Processing Record 35 of Set 4 | namibe
# Processing Record 36 of Set 4 | thinadhoo
# Processing Record 37 of Set 4 | kaitangata
# Processing Record 38 of Set 4 | castro
# Processing Record 39 of Set 4 | gallup
# Processing Record 40 of Set 4 | faanui
# Processing Record 41 of Set 4 | henties bay
# Processing Record 42 of Set 4 | batagay-alyta
# Processing Record 43 of Set 4 | thompson
# Processing Record 44 of Set 4 | nerchinsk
# Processing Record 45 of Set 4 | les cayes
# Processing Record 46 of Set 4 | tasiilaq
# Processing Record 47 of Set 4 | daud khel
# Processing Record 48 of Set 4 | sola
# Processing Record 49 of Set 4 | saint george
# Processing Record 50 of Set 4 | eyl
# Processing Record 1 of Set 5 | coquimbo
# Processing Record 2 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 5 | souillac
# Processing Record 4 of Set 5 | jacareacanga
# Processing Record 5 of Set 5 | amahai
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | dunafoldvar
# Processing Record 9 of Set 5 | kahului
# Processing Record 10 of Set 5 | qeshm
# Processing Record 11 of Set 5 | guerrero negro
# Processing Record 12 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 13 of Set 5 | east london
# Processing Record 14 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 15 of Set 5 | antofagasta
# Processing Record 16 of Set 5 | dudinka
# Processing Record 17 of Set 5 | aklavik
# Processing Record 18 of Set 5 | itarema
# Processing Record 19 of Set 5 | tutoia
# Processing Record 20 of Set 5 | villena
# Processing Record 21 of Set 5 | olinda
# Processing Record 22 of Set 5 | linxia
# Processing Record 23 of Set 5 | gotsu
# Processing Record 24 of Set 5 | kruisfontein
# Processing Record 25 of Set 5 | dali
# Processing Record 26 of Set 5 | bambous virieux
# Processing Record 27 of Set 5 | cidreira
# Processing Record 28 of Set 5 | jaguarao
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | cherskiy
# Processing Record 31 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 5 | lac du bonnet
# Processing Record 33 of Set 5 | juneau
# Processing Record 34 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 5 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 36 of Set 5 | saint-philippe
# Processing Record 37 of Set 5 | warmbad
# Processing Record 38 of Set 5 | galich
# Processing Record 39 of Set 5 | manokwari
# Processing Record 40 of Set 5 | banjar
# Processing Record 41 of Set 5 | bangassou
# Processing Record 42 of Set 5 | port hardy
# Processing Record 43 of Set 5 | qui nhon
# Processing Record 44 of Set 5 | kalmunai
# Processing Record 45 of Set 5 | surt
# Processing Record 46 of Set 5 | krasnoselkup
# Processing Record 47 of Set 5 | januaria
# Processing Record 48 of Set 5 | puerto escondido
# Processing Record 49 of Set 5 | beringovskiy
# Processing Record 50 of Set 5 | nabire
# Processing Record 1 of Set 6 | saint-augustin
# Processing Record 2 of Set 6 | conceicao do araguaia
# Processing Record 3 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 6 | lagoa
# Processing Record 5 of Set 6 | qaanaaq
# Processing Record 6 of Set 6 | olafsvik
# Processing Record 7 of Set 6 | banda aceh
# Processing Record 8 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 6 | nuuk
# Processing Record 10 of Set 6 | collie
# Processing Record 11 of Set 6 | kushima
# Processing Record 12 of Set 6 | darhan
# Processing Record 13 of Set 6 | cayenne
# Processing Record 14 of Set 6 | sitka
# Processing Record 15 of Set 6 | port moresby
# Processing Record 16 of Set 6 | betioky
# Processing Record 17 of Set 6 | hualmay
# Processing Record 18 of Set 6 | dejen
# Processing Record 19 of Set 6 | saldanha
# Processing Record 20 of Set 6 | provideniya
# Processing Record 21 of Set 6 | san carlos
# Processing Record 22 of Set 6 | jardim
# Processing Record 23 of Set 6 | ulladulla
# Processing Record 24 of Set 6 | arlit
# Processing Record 25 of Set 6 | perelyub
# Processing Record 26 of Set 6 | vila velha
# Processing Record 27 of Set 6 | melfi
# Processing Record 28 of Set 6 | alexander city
# Processing Record 29 of Set 6 | maningrida
# Processing Record 30 of Set 6 | ugoofaaru
# Processing Record 31 of Set 6 | dingle
# Processing Record 32 of Set 6 | hithadhoo
# Processing Record 33 of Set 6 | princeville
# Processing Record 34 of Set 6 | nishihara
# Processing Record 35 of Set 6 | tura
# Processing Record 36 of Set 6 | mangrol
# Processing Record 37 of Set 6 | vestmannaeyjar
# Processing Record 38 of Set 6 | karratha
# Processing Record 39 of Set 6 | mae sai
# Processing Record 40 of Set 6 | dharchula
# Processing Record 41 of Set 6 | evensk
# Processing Record 42 of Set 6 | kenai
# Processing Record 43 of Set 6 | nuqui
# Processing Record 44 of Set 6 | vardo
# Processing Record 45 of Set 6 | bikin
# Processing Record 46 of Set 6 | broken hill
# Processing Record 47 of Set 6 | ghanzi
# Processing Record 48 of Set 6 | hami
# Processing Record 49 of Set 6 | wamba
# Processing Record 50 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 7 | borovoy
# Processing Record 2 of Set 7 | codajas
# Processing Record 3 of Set 7 | mogok
# Processing Record 4 of Set 7 | komsomolskiy
# Processing Record 5 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 7 | plouzane
# Processing Record 8 of Set 7 | roma
# Processing Record 9 of Set 7 | saint-pierre
# Processing Record 10 of Set 7 | prainha
# Processing Record 11 of Set 7 | kribi
# Processing Record 12 of Set 7 | poum
# Processing Record 13 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 7 | kannauj
# Processing Record 15 of Set 7 | madison heights
# Processing Record 16 of Set 7 | sur
# Processing Record 17 of Set 7 | buala
# Processing Record 18 of Set 7 | turan
# Processing Record 19 of Set 7 | tisul
# Processing Record 20 of Set 7 | adrar
# Processing Record 21 of Set 7 | somovo
# Processing Record 22 of Set 7 | lavrentiya
# Processing Record 23 of Set 7 | ust-ishim
# Processing Record 24 of Set 7 | ambulu
# Processing Record 25 of Set 7 | cabadiangan
# Processing Record 26 of Set 7 | mugango
# Processing Record 27 of Set 7 | dhar
# Processing Record 28 of Set 7 | varhaug
# Processing Record 29 of Set 7 | ulaangom
# Processing Record 30 of Set 7 | shellbrook
# Processing Record 31 of Set 7 | guilin
# Processing Record 32 of Set 7 | ahar
# Processing Record 33 of Set 7 | srednekolymsk
# Processing Record 34 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 7 | pevek
# Processing Record 36 of Set 7 | port hedland
# Processing Record 37 of Set 7 | douentza
# Processing Record 38 of Set 7 | manali
# Processing Record 39 of Set 7 | girne
# Processing Record 40 of Set 7 | sefton
# Processing Record 41 of Set 7 | sorland
# Processing Record 42 of Set 7 | ponta delgada
# Processing Record 43 of Set 7 | zavyalovo
# Processing Record 44 of Set 7 | channel-port aux basques
# Processing Record 45 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 7 | boa vista
# Processing Record 47 of Set 7 | sisimiut
# Processing Record 48 of Set 7 | oussouye
# Processing Record 49 of Set 7 | isaka
# Processing Record 50 of Set 7 | barra do garcas
# Processing Record 1 of Set 8 | madang
# Processing Record 2 of Set 8 | ratisbon
# City not found. Skipping...
# Processing Record 3 of Set 8 | xam nua
# Processing Record 4 of Set 8 | andenes
# Processing Record 5 of Set 8 | princeton
# Processing Record 6 of Set 8 | gat
# Processing Record 7 of Set 8 | los llanos de aridane
# Processing Record 8 of Set 8 | bentiu
# Processing Record 9 of Set 8 | mackay
# Processing Record 10 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 8 | iqaluit
# Processing Record 12 of Set 8 | moose jaw
# Processing Record 13 of Set 8 | bismarck
# Processing Record 14 of Set 8 | isabela
# Processing Record 15 of Set 8 | lesogorsk
# Processing Record 16 of Set 8 | boralday
# Processing Record 17 of Set 8 | isangel
# Processing Record 18 of Set 8 | pyay
# Processing Record 19 of Set 8 | ambunti
# Processing Record 20 of Set 8 | sabang
# Processing Record 21 of Set 8 | baldwin
# Processing Record 22 of Set 8 | vila franca do campo
# Processing Record 23 of Set 8 | mitsamiouli
# Processing Record 24 of Set 8 | cabo san lucas
# Processing Record 25 of Set 8 | noumea
# Processing Record 26 of Set 8 | svetlyy
# Processing Record 27 of Set 8 | nome
# Processing Record 28 of Set 8 | dickinson
# Processing Record 29 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 8 | hobyo
# Processing Record 31 of Set 8 | margate
# Processing Record 32 of Set 8 | burica
# City not found. Skipping...
# Processing Record 33 of Set 8 | oga
# Processing Record 34 of Set 8 | oranjemund
# Processing Record 35 of Set 8 | kloulklubed
# Processing Record 36 of Set 8 | pakpattan
# Processing Record 37 of Set 8 | sulangan
# Processing Record 38 of Set 8 | sunndalsora
# Processing Record 39 of Set 8 | kannad
# Processing Record 40 of Set 8 | geraldton
# Processing Record 41 of Set 8 | sile
# Processing Record 42 of Set 8 | yar-sale
# Processing Record 43 of Set 8 | bikramganj
# Processing Record 44 of Set 8 | peski
# Processing Record 45 of Set 8 | moose factory
# Processing Record 46 of Set 8 | cockburn town
# Processing Record 47 of Set 8 | muyezerskiy
# Processing Record 48 of Set 8 | tabou
# Processing Record 49 of Set 8 | port lincoln
# Processing Record 50 of Set 8 | college
# Processing Record 1 of Set 9 | logansport
# Processing Record 2 of Set 9 | berlevag
# Processing Record 3 of Set 9 | klaksvik
# Processing Record 4 of Set 9 | muli
# Processing Record 5 of Set 9 | rawson
# Processing Record 6 of Set 9 | lobito
# Processing Record 7 of Set 9 | biloela
# Processing Record 8 of Set 9 | khatanga
# Processing Record 9 of Set 9 | abu zabad
# Processing Record 10 of Set 9 | chingirlau
# Processing Record 11 of Set 9 | leua
# Processing Record 12 of Set 9 | alice springs
# Processing Record 13 of Set 9 | sao joao da barra
# Processing Record 14 of Set 9 | airai
# Processing Record 15 of Set 9 | salina
# Processing Record 16 of Set 9 | hamilton
# Processing Record 17 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 18 of Set 9 | panguna
# Processing Record 19 of Set 9 | george town
# Processing Record 20 of Set 9 | nileshwar
# Processing Record 21 of Set 9 | palauig
# Processing Record 22 of Set 9 | monroe
# Processing Record 23 of Set 9 | byron bay
# Processing Record 24 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 25 of Set 9 | rockland
# Processing Record 26 of Set 9 | walvis bay
# Processing Record 27 of Set 9 | balkanabat
# Processing Record 28 of Set 9 | wattegama
# Processing Record 29 of Set 9 | pisco
# Processing Record 30 of Set 9 | lisakovsk
# Processing Record 31 of Set 9 | madimba
# Processing Record 32 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 33 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 9 | yingshang
# City not found. Skipping...
# Processing Record 35 of Set 9 | svetlaya
# Processing Record 36 of Set 9 | grand gaube
# Processing Record 37 of Set 9 | gazni
# City not found. Skipping...
# Processing Record 38 of Set 9 | khandbari
# Processing Record 39 of Set 9 | manado
# Processing Record 40 of Set 9 | gloucester
# Processing Record 41 of Set 9 | pacific grove
# Processing Record 42 of Set 9 | port macquarie
# Processing Record 43 of Set 9 | arkhangelsk
# Processing Record 44 of Set 9 | muzhi
# Processing Record 45 of Set 9 | awjilah
# Processing Record 46 of Set 9 | coello
# Processing Record 47 of Set 9 | caravelas
# Processing Record 48 of Set 9 | yeban
# Processing Record 49 of Set 9 | hasaki
# Processing Record 50 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 10 | mariana
# Processing Record 2 of Set 10 | ust-tsilma
# Processing Record 3 of Set 10 | uryupinsk
# Processing Record 4 of Set 10 | illintsi
# Processing Record 5 of Set 10 | samarai
# Processing Record 6 of Set 10 | kuusamo
# Processing Record 7 of Set 10 | dehloran
# Processing Record 8 of Set 10 | hambantota
# Processing Record 9 of Set 10 | namatanai
# Processing Record 10 of Set 10 | andrews
# Processing Record 11 of Set 10 | fort nelson
# Processing Record 12 of Set 10 | xuzhou
# Processing Record 13 of Set 10 | ahipara
# Processing Record 14 of Set 10 | mikhaylovka
# Processing Record 15 of Set 10 | smithers
# Processing Record 16 of Set 10 | arkhangelskoye
# Processing Record 17 of Set 10 | port hawkesbury
# Processing Record 18 of Set 10 | mattru
# Processing Record 19 of Set 10 | ryde
# Processing Record 20 of Set 10 | waingapu
# Processing Record 21 of Set 10 | kilindoni
# Processing Record 22 of Set 10 | santa ines
# Processing Record 23 of Set 10 | ushtobe
# Processing Record 24 of Set 10 | magadan
# Processing Record 25 of Set 10 | imbituba
# Processing Record 26 of Set 10 | ust-nera
# Processing Record 27 of Set 10 | ivybridge
# Processing Record 28 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 29 of Set 10 | reyes
# Processing Record 30 of Set 10 | cervo
# Processing Record 31 of Set 10 | malatya
# Processing Record 32 of Set 10 | omsukchan
# Processing Record 33 of Set 10 | portland
# Processing Record 34 of Set 10 | aguimes
# Processing Record 35 of Set 10 | mount gambier
# Processing Record 36 of Set 10 | santa engracia
# Processing Record 37 of Set 10 | bela
# Processing Record 38 of Set 10 | besikduzu
# Processing Record 39 of Set 10 | yamada
# Processing Record 40 of Set 10 | carmen
# Processing Record 41 of Set 10 | pochutla
# Processing Record 42 of Set 10 | waitara
# Processing Record 43 of Set 10 | sao jose da coroa grande
# Processing Record 44 of Set 10 | atar
# Processing Record 45 of Set 10 | vogosca
# Processing Record 46 of Set 10 | mendi
# Processing Record 47 of Set 10 | ahmadnagar
# Processing Record 48 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 49 of Set 10 | camocim
# Processing Record 50 of Set 10 | san andres
# Processing Record 1 of Set 11 | ayan
# Processing Record 2 of Set 11 | paita
# Processing Record 3 of Set 11 | piripiri
# Processing Record 4 of Set 11 | bathsheba
# Processing Record 5 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 6 of Set 11 | charagua
# Processing Record 7 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 11 | valparaiso
# Processing Record 9 of Set 11 | jining
# Processing Record 10 of Set 11 | cap malheureux
# Processing Record 11 of Set 11 | fairbanks
# Processing Record 12 of Set 11 | sarh
# Processing Record 13 of Set 11 | buraydah
# Processing Record 14 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 11 | taywarah
# Processing Record 16 of Set 11 | hay river
# Processing Record 17 of Set 11 | zhanakorgan
# Processing Record 18 of Set 11 | bose
# Processing Record 19 of Set 11 | mae hong son
# Processing Record 20 of Set 11 | wairoa
# Processing Record 21 of Set 11 | sarkand
# Processing Record 22 of Set 11 | harper
# Processing Record 23 of Set 11 | ambilobe
# Processing Record 24 of Set 11 | heihe
# Processing Record 25 of Set 11 | omboue
# Processing Record 26 of Set 11 | chuy
# Processing Record 27 of Set 11 | inirida
# Processing Record 28 of Set 11 | shelburne
# Processing Record 29 of Set 11 | manta
# Processing Record 30 of Set 11 | ixtapa
# Processing Record 31 of Set 11 | calama
# Processing Record 32 of Set 11 | shache
# Processing Record 33 of Set 11 | celestun
# Processing Record 34 of Set 11 | jiaohe
# Processing Record 35 of Set 11 | turayf
# Processing Record 36 of Set 11 | dawlatabad
# Processing Record 37 of Set 11 | altamira
# Processing Record 38 of Set 11 | bubaque
# Processing Record 39 of Set 11 | suhbaatar
# Processing Record 40 of Set 11 | skovorodino
# Processing Record 41 of Set 11 | constitucion
# Processing Record 42 of Set 11 | jiangyou
# Processing Record 43 of Set 11 | grindavik
# Processing Record 44 of Set 11 | katsuyama
# Processing Record 45 of Set 11 | xushan
# Processing Record 46 of Set 11 | saint anthony
# Processing Record 47 of Set 11 | raga
# Processing Record 48 of Set 11 | bandarbeyla
# Processing Record 49 of Set 11 | tabuk
# Processing Record 50 of Set 11 | nova olinda do norte
# Processing Record 1 of Set 12 | port-gentil
# Processing Record 2 of Set 12 | vangaindrano
# Processing Record 3 of Set 12 | aykhal
# Processing Record 4 of Set 12 | zeerust
# Processing Record 5 of Set 12 | anito
# Processing Record 6 of Set 12 | cao bang
# Processing Record 7 of Set 12 | fenoarivo
# Processing Record 8 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 9 of Set 12 | massaguet
# Processing Record 10 of Set 12 | tezu
# Processing Record 11 of Set 12 | mantua
# Processing Record 12 of Set 12 | qiongshan
# Processing Record 13 of Set 12 | tigzirt
# Processing Record 14 of Set 12 | chontalpa
# Processing Record 15 of Set 12 | aquiraz
# Processing Record 16 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 12 | taltal
# Processing Record 18 of Set 12 | saint-georges
# Processing Record 19 of Set 12 | la libertad
# Processing Record 20 of Set 12 | pitimbu
# Processing Record 21 of Set 12 | muros
# Processing Record 22 of Set 12 | le port
# Processing Record 23 of Set 12 | moss vale
# Processing Record 24 of Set 12 | magway
# Processing Record 25 of Set 12 | kortkeros
# Processing Record 26 of Set 12 | porto walter
# Processing Record 27 of Set 12 | chapulhuacan
# Processing Record 28 of Set 12 | gimli
# Processing Record 29 of Set 12 | santander
# Processing Record 30 of Set 12 | san carlos de bariloche
# Processing Record 31 of Set 12 | maltahohe
# Processing Record 32 of Set 12 | yairipok
# Processing Record 33 of Set 12 | tokur
# Processing Record 34 of Set 12 | vitimskiy
# City not found. Skipping...
# Processing Record 35 of Set 12 | ravar
# Processing Record 36 of Set 12 | bosaso
# Processing Record 37 of Set 12 | hinton
# Processing Record 38 of Set 12 | hirara
# Processing Record 39 of Set 12 | bafq
# Processing Record 40 of Set 12 | kerugoya
# Processing Record 41 of Set 12 | alofi
# Processing Record 42 of Set 12 | khandagayty
# Processing Record 43 of Set 12 | coihueco
# Processing Record 44 of Set 12 | vanimo
# Processing Record 45 of Set 12 | abonnema
# Processing Record 46 of Set 12 | khuzhir
# Processing Record 47 of Set 12 | lake cowichan
# Processing Record 48 of Set 12 | baguanos
# Processing Record 49 of Set 12 | arawa
# Processing Record 50 of Set 12 | pundaguitan
# Processing Record 1 of Set 13 | ornskoldsvik
# Processing Record 2 of Set 13 | lancaster
# Processing Record 3 of Set 13 | hailey
# Processing Record 4 of Set 13 | lyuban
# Processing Record 5 of Set 13 | oktyabrskiy
# Processing Record 6 of Set 13 | champasak
# Processing Record 7 of Set 13 | xining
# Processing Record 8 of Set 13 | carauari
# Processing Record 9 of Set 13 | vostok
# Processing Record 10 of Set 13 | gornopravdinsk
# Processing Record 11 of Set 13 | lakatoro
# Processing Record 12 of Set 13 | najran
# Processing Record 13 of Set 13 | naze
# Processing Record 14 of Set 13 | gimbi
# Processing Record 15 of Set 13 | yulara
# Processing Record 16 of Set 13 | beberibe
# Processing Record 17 of Set 13 | boone
# Processing Record 18 of Set 13 | toledo
# Processing Record 19 of Set 13 | yerbogachen
# Processing Record 20 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 13 | tual
# Processing Record 22 of Set 13 | vaitape
# Processing Record 23 of Set 13 | mormugao
# Processing Record 24 of Set 13 | barcelona
# Processing Record 25 of Set 13 | vaovai
# City not found. Skipping...
# Processing Record 26 of Set 13 | naujamiestis
# Processing Record 27 of Set 13 | itoman
# Processing Record 28 of Set 13 | sept-iles
# Processing Record 29 of Set 13 | bonfim
# Processing Record 30 of Set 13 | shigony
# Processing Record 31 of Set 13 | buchanan
# Processing Record 32 of Set 13 | qinnan
# Processing Record 33 of Set 13 | sawakin
# Processing Record 34 of Set 13 | codrington
# Processing Record 35 of Set 13 | sahuaripa
# Processing Record 36 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 37 of Set 13 | auki
# Processing Record 38 of Set 13 | suna
# Processing Record 39 of Set 13 | kitaotao
# Processing Record 40 of Set 13 | paamiut
# Processing Record 41 of Set 13 | puro
# Processing Record 42 of Set 13 | makubetsu
# Processing Record 43 of Set 13 | moron
# Processing Record 44 of Set 13 | gushi
# Processing Record 45 of Set 13 | puerto palomas
# Processing Record 46 of Set 13 | kokopo
# Processing Record 47 of Set 13 | alamos
# Processing Record 48 of Set 13 | the valley
# Processing Record 49 of Set 13 | gazli
# Processing Record 50 of Set 13 | sishui
# Processing Record 1 of Set 14 | padang
# Processing Record 2 of Set 14 | taraz
# Processing Record 3 of Set 14 | yumen
# Processing Record 4 of Set 14 | cururupu
# Processing Record 5 of Set 14 | westport
# Processing Record 6 of Set 14 | masallatah
# Processing Record 7 of Set 14 | puri
# Processing Record 8 of Set 14 | zenzeli
# Processing Record 9 of Set 14 | santiago
# Processing Record 10 of Set 14 | parnaiba
# Processing Record 11 of Set 14 | barabai
# Processing Record 12 of Set 14 | laguna
# Processing Record 13 of Set 14 | san enrique
# Processing Record 14 of Set 14 | nagybajom
# Processing Record 15 of Set 14 | gunnedah
# Processing Record 16 of Set 14 | litoral del san juan
# City not found. Skipping...
# Processing Record 17 of Set 14 | tomatlan
# Processing Record 18 of Set 14 | shihezi
# Processing Record 19 of Set 14 | amuntai
# Processing Record 20 of Set 14 | troitskoye
# Processing Record 21 of Set 14 | makungu
# Processing Record 22 of Set 14 | riyadh
# Processing Record 23 of Set 14 | vila do maio
# Processing Record 24 of Set 14 | kawalu
# Processing Record 25 of Set 14 | chapais
# Processing Record 26 of Set 14 | diffa
# Processing Record 27 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 14 | morozovsk
# Processing Record 29 of Set 14 | san antonio
# Processing Record 30 of Set 14 | pavlodar
# Processing Record 31 of Set 14 | cabedelo
# Processing Record 32 of Set 14 | mizan teferi
# Processing Record 33 of Set 14 | santa catarina de tepehuanes
# Processing Record 34 of Set 14 | khrenovoye
# Processing Record 35 of Set 14 | ekhabi
# Processing Record 36 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 14 | simao
# Processing Record 38 of Set 14 | abha
# Processing Record 39 of Set 14 | wuwei
# Processing Record 40 of Set 14 | aksehir
# Processing Record 41 of Set 14 | hangu
# Processing Record 42 of Set 14 | richards bay
# Processing Record 43 of Set 14 | plymouth
# Processing Record 44 of Set 14 | huarmey
# Processing Record 45 of Set 14 | bar harbor
# Processing Record 46 of Set 14 | chernoistochinsk
# Processing Record 47 of Set 14 | praia
# Processing Record 48 of Set 14 | kommunisticheskiy
# Processing Record 49 of Set 14 | carson city
# Processing Record 50 of Set 14 | tlahualilo
# City not found. Skipping...
# Processing Record 1 of Set 15 | alekseyevsk
# Processing Record 2 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 3 of Set 15 | gazojak
# Processing Record 4 of Set 15 | san pedro
# Processing Record 5 of Set 15 | ig
# City not found. Skipping...
# Processing Record 6 of Set 15 | bansud
# Processing Record 7 of Set 15 | afrikanda
# Processing Record 8 of Set 15 | vila
# Processing Record 9 of Set 15 | monatele
# City not found. Skipping...
# Processing Record 10 of Set 15 | gigmoto
# Processing Record 11 of Set 15 | chikwawa
# Processing Record 12 of Set 15 | prince rupert
# Processing Record 13 of Set 15 | jimma
# Processing Record 14 of Set 15 | chaman
# Processing Record 15 of Set 15 | pokhara
# Processing Record 16 of Set 15 | vao
# Processing Record 17 of Set 15 | thayetmyo
# Processing Record 18 of Set 15 | saint-francois
# Processing Record 19 of Set 15 | inuvik
# Processing Record 20 of Set 15 | tromso
# Processing Record 21 of Set 15 | axim
# Processing Record 22 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 15 | eureka
# Processing Record 24 of Set 15 | jungapeo
# Processing Record 25 of Set 15 | esperance
# Processing Record 26 of Set 15 | jacqueville
# Processing Record 27 of Set 15 | eshowe
# Processing Record 28 of Set 15 | waipawa
# Processing Record 29 of Set 15 | golden
# Processing Record 30 of Set 15 | khasan
# Processing Record 31 of Set 15 | kaka
# Processing Record 32 of Set 15 | piacabucu
# Processing Record 33 of Set 15 | umea
# Processing Record 34 of Set 15 | jiuquan
# Processing Record 35 of Set 15 | lahaina
# Processing Record 36 of Set 15 | quelimane
# Processing Record 37 of Set 15 | morgan city
# Processing Record 38 of Set 15 | capoterra
# Processing Record 39 of Set 15 | ludvika
# Processing Record 40 of Set 15 | sorsk
# Processing Record 41 of Set 15 | goderich
# Processing Record 42 of Set 15 | leh
# Processing Record 43 of Set 15 | teya
# Processing Record 44 of Set 15 | xique-xique
# Processing Record 45 of Set 15 | madras
# Processing Record 46 of Set 15 | tuskegee
# Processing Record 47 of Set 15 | kushiro
# Processing Record 48 of Set 15 | ballina
# Processing Record 49 of Set 15 | areosa
# Processing Record 50 of Set 15 | pijijiapan
# Processing Record 1 of Set 16 | santa cruz de la palma
# Processing Record 2 of Set 16 | kachiry
# Processing Record 3 of Set 16 | esil
# Processing Record 4 of Set 16 | labrea
# Processing Record 5 of Set 16 | aanekoski
# Processing Record 6 of Set 16 | terrace
# Processing Record 7 of Set 16 | deputatskiy
# Processing Record 8 of Set 16 | pandan
# Processing Record 9 of Set 16 | mutoko
# Processing Record 10 of Set 16 | woodhaven
# Processing Record 11 of Set 16 | puerto baquerizo moreno
# Processing Record 12 of Set 16 | labuhan
# Processing Record 13 of Set 16 | tena
# Processing Record 14 of Set 16 | baykit
# Processing Record 15 of Set 16 | tateyama
# Processing Record 16 of Set 16 | kurayoshi
# Processing Record 17 of Set 16 | eluru
# Processing Record 18 of Set 16 | abnub
# Processing Record 19 of Set 16 | ust-omchug
# Processing Record 20 of Set 16 | cobija
# Processing Record 21 of Set 16 | madiun
# Processing Record 22 of Set 16 | naberera
# Processing Record 23 of Set 16 | mago
# Processing Record 24 of Set 16 | lusambo
# Processing Record 25 of Set 16 | chimoio
# Processing Record 26 of Set 16 | ust-ilimsk
# Processing Record 27 of Set 16 | tommot
# Processing Record 28 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 16 | kieta
# Processing Record 30 of Set 16 | hoima
# Processing Record 31 of Set 16 | bathurst
# Processing Record 32 of Set 16 | carroll
# Processing Record 33 of Set 16 | plaster rock
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 720

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data) # YOUR CODE HERE

# %%
# Display sample data
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Tipitapa  12.1973  -86.0971     74.86        90          71        5.23
# 1    Fortuna  40.5982 -124.1573     43.99       100          16        2.15
# 2    Guiyang  26.5833  106.7167     57.69        77         100        2.24
# 3    Talnakh  69.4865   88.3972    -30.51        99          65        0.69
# 4    Ushuaia -54.8000  -68.3000     53.26        43          75        8.05
# 5     Marawi   7.9986  124.2928     72.36        85         100        2.64
# 6    Husavik  66.0449  -17.3389     43.43        81         100       18.54
# 7  Toamasina -18.1667   49.3833     73.40        88          75        1.14
# 8     Barrow  71.2906 -156.7887     24.82        80           0       16.11
# 9     Kodiak  57.7900 -152.4072     44.11        93         100       21.85
#
#   Country      Description                 Date
# 0      NI    broken clouds  2022-11-17 03:17:00
# 1      US       few clouds  2022-11-17 03:20:34
# 2      CN  overcast clouds  2022-11-17 03:20:34
# 3      RU    broken clouds  2022-11-17 03:20:23
# 4      AR    broken clouds  2022-11-17 03:15:22
# 5      PH  overcast clouds  2022-11-17 03:20:35
# 6      IS  overcast clouds  2022-11-17 03:20:35
# 7      MG    broken clouds  2022-11-17 03:20:35
# 8      US        clear sky  2022-11-17 03:15:20
# 9      US       light rain  2022-11-17 03:20:36

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[new_column_order]

# Display sample data
# YOUR CODE HERE
city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Tipitapa      NI  12.1973  -86.0971     74.86        90          71
# 1   Fortuna      US  40.5982 -124.1573     43.99       100          16
# 2   Guiyang      CN  26.5833  106.7167     57.69        77         100
# 3   Talnakh      RU  69.4865   88.3972    -30.51        99          65
# 4   Ushuaia      AR -54.8000  -68.3000     53.26        43          75
#
#    Wind Speed      Description
# 0        5.23    broken clouds
# 1        2.15       few clouds
# 2        2.24  overcast clouds
# 3        0.69    broken clouds
# 4        8.05    broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
